# %%
from Cam_Scanner_module import camscan 
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = cv2.imread("im3.jpeg")
print(img.shape)
plt.imshow(img)
# Out:
# (1280, 916, 3)

# %%
img1 = cv2.resize(img,(int(img.shape[1]/5),int(img.shape[0]/5)))

# %%
plt.imshow(img1)

# %%
scanned_img = camscan(img1,0.04)
# Out:
# before allignment :
# [[[ 74  19]]
#
#  [[ 12 190]]
#
#  [[116 229]]
#
#  [[175  56]]]
# after allignment :
# [[ 74.  19.]
#  [175.  56.]
#  [116. 229.]
#  [ 12. 190.]]
